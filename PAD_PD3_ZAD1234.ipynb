# %%
import pandas as pd

# %%
#Zad 1
df=pd.read_csv('/Users/michalluniewski/Documents/PAD/03_PAD/Zadania_domowe/PAD_03_PD.csv', sep=';')
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
# [800 rows x 8 columns]

# %%
#Replace missing values with the most frequent value in the column
cols = ['Country','owns_car', "owns_TV", 'owns_house', 'owns_Phone', 'Age', 'gender']
df[cols]=df[cols].fillna(df.mode().iloc[0])
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
# [800 rows x 8 columns]

# %%
df.groupby('Country').count()
# Out:
#           ID  owns_car  owns_TV  owns_house  owns_Phone  gender  Age
# Country
# A        335       335      335         335         335     335  335
# B        201       201      201         201         201     201  201
# C        186       186      186         186         186     186  186
# D         78        78       78          78          78      78   78

# %%
#Zad 2
df['Owned_Goods'] = df.owns_car + df.owns_TV + df.owns_house + df.owns_Phone
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age  \
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
#      Owned_Goods
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# ...

# %%
#Zad 3
df.groupby('gender').mean().Owned_Goods.round(2)
# Out:
# gender
# K    2.79
# M    0.91
# Name: Owned_Goods, dtype: float64

# %%
#Zad 4
CountryMean = df.groupby('Country').mean().Owned_Goods.round(2)
AgeMin = df.groupby('Country').min().Age
NewDf = pd.merge(CountryMean, AgeMin, how='outer', on='Country')
NewDf
# Out:
#          Owned_Goods  Age
# Country
# A               0.87   18
# B               1.45   18
# C               3.02   18
# D               4.00   18
